# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('bikesharinghours.csv')
df.head()
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
# 2        3  1/1/2011       1   0     1   2        0        6           0
# 3        4  1/1/2011       1   0     1   3        0        6           0
# 4        5  1/1/2011       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# setting params

# %%
params = {'legend.fontsize':'x-large','figure.figsize': (20,10),'axes.labelsize':'x-large', 'axes.titlesize':'x-large', 'xtick.labelsize': 'x-large', 'ytick.labelsize': 'x-large'}

# %%
sns.set_style('whitegrid')
sns.set_context('talk')
plt.rcParams.update(params)
pd.options.display.max_colwidth = 600

# %%
print("Shape of dataset::{}".format(df.shape))
# Out:
# Shape of dataset::(17379, 17)

# %%
# pandas display data frames as tables
from IPython.display import display, HTML
display(df.head())
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
# 2        3  1/1/2011       1   0     1   2        0        6           0
# 3        4  1/1/2011       1   0     1   3        0        6           0
# 4        5  1/1/2011       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
#Standardize Attribute Names

# %%
df.rename(columns={'instant':'rec_id', 
                  'dteday':'datetime',
                  'holiday':'is_holiday',
                  'workingday':'is_workingday',
                   'weathersit':'weather_condition',
                      'hum':'humidity',
                      'mnth':'month',
                      'cnt':'total_count',
                      'hr':'hour',
                      'yr':'year'},inplace=True)

# %%
df.dtypes
# Out:
# rec_id                 int64
# datetime              object
# season                 int64
# year                   int64
# month                  int64
# hour                   int64
# is_holiday             int64
# weekday                int64
# is_workingday          int64
# weather_condition      int64
# temp                 float64
# atemp                float64
# humidity             float64
# windspeed            float64
# casual                 int64
# registered             int64
# total_count            int64
# dtype: object

# %%
# date time conversion
df['datetime'] = pd.to_datetime(df.datetime)

# %%
df.dtypes
# Out:
# rec_id                        int64
# datetime             datetime64[ns]
# season                        int64
# year                          int64
# month                         int64
# hour                          int64
# is_holiday                    int64
# weekday                       int64
# is_workingday                 int64
# weather_condition             int64
# temp                        float64
# atemp                       float64
# humidity                    float64
# windspeed                   float64
# casual                        int64
# registered                    int64
# total_count                   int64
# dtype: object

# %%
#Visualize Attributes, Trends and Relationships
#Hourly distribution of Total Counts
#Seasons are encoded as 1:spring, 2:summer, 3:fall, 4:winter
#Exercise: Convert season names to readable strings and visualize data again

sns.pointplot(data=df, x='hour', y='total_count', hue='season')
plt.title('season wise hourly distribution')
plt.show()

# %%
#The above plot shows peaks around 8am and 5pm (office hours)
#Overall higher usage in the second half of the day

# %%
# year wise distribution
sns.pointplot(data=df, x='hour', y='total_count', hue='year')
plt.title('year wise hourly distribution')
plt.show()

# %%
#weekday wise hourly count.
sns.pointplot(data=df, x='hour', y='total_count', hue='weekday')
plt.title('weekday wise hourly distribution')
plt.show()

# %%
#Weekends (0 and 6) and Weekdays (1-5) show different usage trends with weekend's peak usage in during afternoon hours
#Weekdays follow the overall trend, similar to one visualized in the previous plot
#Weekdays have higher usage as compared to weekends
#It would be interesting to see the trends for casual and registered users separately

# %%
#plt.boxplot(data=df, x='hour', y='total_count')
because there is scope of y argument in plt.boxplot (matpotlib)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-a1ef13740b36> in <module>
# ----> 1 plt.boxplot(data=df, x='hour', y='total_count')
#
# TypeError: boxplot() got an unexpected keyword argument 'y'

# %%
sns.boxplot(data=df, x='hour', y='total_count')
plt.title('Box plot for hourly distribution of counts')
plt.show()

# %%
#we an see here a singnificant outliers from 10-15 hour and outliers between 21-23//
# we can see max number of counts in 8th hour & 17th hour

# %%
sns.barplot(data=df, x='month', y='total_count')
plt.title('monthly distirbution of counts')
plt.show()

# %%
# above graph is reflecting maximum number of counts in 6,7,8 & 9 month

# %%
df['season'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
spring= df[df.season==1][['month', 'weekday', 'total_count']]
summer= df[df.season==2][['month', 'weekday', 'total_count']]
fall= df[df.season==3][['month', 'weekday', 'total_count']]
winter= df[df.season==4][['month', 'weekday', 'total_count']]

# %%
spring.head()
# Out:
#    month  weekday  total_count
# 0      1        6           16
# 1      1        6           40
# 2      1        6           32
# 3      1        6           13
# 4      1        6            1

# %%
fig,ax= plt.subplots(nrows=2, ncols=2)
sns.barplot(data=spring, x='month', y='total_count', ax=ax[0][0])
ax[0][0].set(title='Spring')

sns.barplot(data=summer, x='month', y='total_count', ax=ax[0][1])
ax[0][1].set(title='summer')

sns.barplot(data=fall, x='month', y='total_count', ax=ax[1][0])
ax[1][0].set(title='fall')

sns.barplot(data=winter, x='month', y='total_count', ax=ax[1][1])
ax[1][1].set(title='winter')
plt.show()

# %%
# year wise violin plot

# %%
x = sns.violinplot(data=df, x = 'year', y ='total_count')
x.set(title= 'Violin plot')
plt.show()

# %%
#Working Day Vs Holiday Distribution
fig,(ax1,ax2) = plt.subplots(ncols=2)
sns.barplot(data=df, x='is_holiday', y='total_count', hue='season', ax=ax1)
sns.barplot(data=df, x='is_workingday', y='total_count', hue='season', ax=ax2)
plt.show()

# %%
fig,(ax1,ax2)= plt.subplots(ncols=2)
sns.boxplot(data=df[['total_count',
                         'casual','registered']],ax=ax1)
sns.boxplot(data=df[['temp','windspeed']],ax=ax2)
plt.show()

# %%
dfcorr = df.corr()

# %%
sns.heatmap(dfcorr, cmap='Reds', annot=True)

# %%
df1 = df.copy()

# %%
df1.drop('datetime', inplace=True,  axis=1)

# %%
df1.head()
# Out:
#    rec_id  season  year  month  hour  is_holiday  weekday  is_workingday  \
# 0       1       1     0      1     0           0        6              0
# 1       2       1     0      1     1           0        6              0
# 2       3       1     0      1     2           0        6              0
# 3       4       1     0      1     3           0        6              0
# 4       5       1     0      1     4           0        6              0
#
#    weather_condition  temp   atemp  humidity  windspeed  casual  registered  \
# 0                  1  0.24  0.2879      0.81        0.0       3          13
# 1                  1  0.22  0.2727      0.80        0.0       8          32
# 2                  1  0.22  0.2727      0.80        0.0       5          27
# 3                  1  0.24  0.2879      0.75        0.0       3          10
# 4                  1  0.24  0.2879      0.75        0.0       0           1
#
#    total_count
# 0           16
# 1           40
# 2           32
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score, mean_squared_error

# %%
lr = LinearRegression()

# %%
x=df1.iloc[:,0:-1]
y=df1.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=.33, random_state=47)
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 1.0

# %%
predict = lr.predict(x_test)

# %%
print(r2_score(y_test,predict))
print(mean_squared_error(y_test,predict))
# Out:
# 1.0
# 8.636281613216642e-22

# %%
t = np.array([1, 1, 0, 1, 0, 0, 6, 0,1, 0.24, 0.2879, 0.81, 0.0, 3, 13])

# %%
td = t.reshape(1,-1)

# %%
lr.predict(td)
# Out:
# array([16.])

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc= dtc.predict(x_test)

# %%
print(r2_score(y_test,preddtc))
print(mean_squared_error(y_test,preddtc))
# Out:
# 0.9958392912266006
# 133.99232914923292

# %%
import pickle
saved_model = pickle.dumps(lr)
saved_model
# Out:
# b'\x80\x03csklearn.linear_model.base\nLinearRegression\nq\x00)\x81q\x01}q\x02(X\r\x00\x00\x00fit_interceptq\x03\x88X\t\x00\x00\x00normalizeq\x04\x89X\x06\x00\x00\x00copy_Xq\x05\x88X\x06\x00\x00\x00n_jobsq\x06NX\x05\x00\x00\x00coef_q\x07cnumpy.core.multiarray\n_reconstruct\nq\x08cnumpy\nndarray\nq\tK\x00\x85q\nC\x01bq\x0b\x87q\x0cRq\r(K\x01K\x0f\x85q\x0ecnumpy\ndtype\nq\x0fX\x02\x00\x00\x00f8q\x10K\x00K\x01\x87q\x11Rq\x12(K\x03X\x01\x00\x00\x00<q\x13NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00tq\x14b\x89Cx[\xc74\x15\xae\xa9\xfa<\x00\x00\x00\x00\x00\x00\x15\xbd\x00\x00\x00\x00x\xfe_\xbd\x00\x00\x00\x00\x00\xe3!\xbd\x00\x00\x00\x00@Y\x0e\xbd\x00\x00\x00\x00V\x82\xf5\xbc\x00\x00\x00\x00h\xf8\xd8\xbc\x00\x00\x00\x80\xac\x7f2\xbd\x00\x00\x00\x008\xc8\x18=\x00\x00\x00\x00J\x9aJ\xbd\x00\x00\x00\x00\xbc\xf3)\xbd\x00\x00\x00@S@.\xbd\x00\x00\x00\x00(\x8e\x1f\xbd\xf7\xff\xff\xff\xff\xff\xef?\x05\x00\x00\x00\x00\x00\xf0?q\x15tq\x16bX\t\x00\x00\x00_residuesq\x17cnumpy.core.multiarray\nscalar\nq\x18h
# ...

# %%
load_model= pickle.loads(saved_model)
load_model.predict(x_test)
# Out:
# array([303., 558., 313., ..., 159., 160., 649.])
