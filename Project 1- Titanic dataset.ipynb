# %%
# !pip install mysql-connector

# %%
import mysql.connector
con=mysql.connector.connect(
    host = "127.0.0.1",
    port = "3306",
    username="root",
    password="zeeshan@449",
    database="titan")

# %%
import pandas as pd

# %%
df = pd.read_sql_query("select * from titanicnew", con)

# %%
df.head()
# Out:
#    Passenger  Survived  Pclass        Name                 Fname     Sex  Age  \
# 0          1         0       3     "Braund      Mr. Owen Harris"    male   22
# 1          2         1       1    "Cumings   Mrs. John Bradley (  female   38
# 2          3         1       3  "Heikkinen          Miss. Laina"  female   26
# 3          4         1       1   "Futrelle   Mrs. Jacques Heath   female   35
# 4          5         0       3      "Allen    Mr. William Henry"    male   35
#
#    Sibsb  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500              S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250              S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500              S

# %%
df.describe()
# Out:
#         Passenger    Survived      Pclass         Age       Sibsb       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean   446.000000    0.383838    2.308642   23.810325    0.523008    0.381594
# std    257.353842    0.486592    0.836071   17.601613    1.102743    0.806057
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%    223.500000    0.000000    2.000000    6.000000    0.000000    0.000000
# 50%    446.000000    0.000000    3.000000   24.000000    0.000000    0.000000
# 75%    668.500000    1.000000    3.000000   35.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204203
# std     49.693412
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329000

# %%
dff= pd.DataFrame(data=df)

# %%
dff
# Out:
#      Passenger  Survived  Pclass              Name                 Fname  \
# 0            1         0       3           "Braund      Mr. Owen Harris"
# 1            2         1       1          "Cumings   Mrs. John Bradley (
# 2            3         1       3        "Heikkinen          Miss. Laina"
# 3            4         1       1         "Futrelle   Mrs. Jacques Heath
# 4            5         0       3            "Allen    Mr. William Henry"
# 5            6         0       3            "Moran            Mr. James"
# 6            7         0       1         "McCarthy        Mr. Timothy J"
# 7            8         0       3          "Palsson   Master. Gosta Leona
# 8            9         1       3          "Johnson   Mrs. Oscar W (Elisa
# 9           10         1       2           "Nasser   Mrs. Nicholas (Adel
# 10          11         1       3        "Sandstrom   Miss. Marguerite Ru
# 11          12         1       1          "Bonnell      Miss. Elizabeth"
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.boxplot(dff['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d6cb59eb8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d6cb69828>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d6cb59d68>],
#  'medians': [<matplotlib.lines.Line2D at 0x22d6cb69eb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22d6cb69f98>],
#  'means': []}

# %%
plt.boxplot(dff['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d6ccdee48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d6cce8518>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d6cdd4780>],
#  'medians': [<matplotlib.lines.Line2D at 0x22d6cce8ba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22d6cce8ef0>],
#  'means': []}

# %%
sns.heatmap(dff.isnull())

# %%
plt.boxplot(dff['Survived'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d6cf23940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d6cf23fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d6cdf7550>],
#  'medians': [<matplotlib.lines.Line2D at 0x22d6cf2f6a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22d6cf2f9e8>],
#  'means': []}

# %%
sns.countplot('Survived',data=dff)
plt.show()                            # 0- not survived, 1-survived, hence we can see less numbers in survived vs non-survived

# %%
dff.groupby(['Sex', 'Survived'])['Survived'].count() #we can see
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
sns.countplot('Age',data=dff)
plt.show()

# %%
sns.countplot('Fare',data=dff)
plt.show()

# %%
dffcorr=dff.corr()

# %%
dffcorr
# Out:
#            Passenger  Survived    Pclass       Age     Sibsb     Parch  \
# Passenger   1.000000 -0.005007 -0.035144  0.037913 -0.057527 -0.001652
# Survived   -0.005007  1.000000 -0.338481  0.010215 -0.035322  0.081629
# Pclass     -0.035144 -0.338481  1.000000 -0.360975  0.083081  0.018443
# Age         0.037913  0.010215 -0.360975  1.000000 -0.184754 -0.048824
# Sibsb      -0.057527 -0.035322  0.083081 -0.184754  1.000000  0.414838
# Parch      -0.001652  0.081629  0.018443 -0.048824  0.414838  1.000000
# Fare        0.012658  0.257307 -0.549500  0.135251  0.159651  0.216225
#
#                Fare
# Passenger  0.012658
# Survived   0.257307
# Pclass    -0.549500
# Age        0.135251
# Sibsb      0.159651
# Parch      0.216225
# Fare       1.000000

# %%
sns.heatmap(dffcorr, cmap="Reds", annot= True)

# %%
# changing catogorical data into muerical data using label encoder...
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
sns.scatterplot(x="Fare", y="Age", hue="Pclass", data=dff)

# %%
df
# Out:
#      Passenger  Survived  Pclass              Name                 Fname  \
# 0            1         0       3           "Braund      Mr. Owen Harris"
# 1            2         1       1          "Cumings   Mrs. John Bradley (
# 2            3         1       3        "Heikkinen          Miss. Laina"
# 3            4         1       1         "Futrelle   Mrs. Jacques Heath
# 4            5         0       3            "Allen    Mr. William Henry"
# 5            6         0       3            "Moran            Mr. James"
# 6            7         0       1         "McCarthy        Mr. Timothy J"
# 7            8         0       3          "Palsson   Master. Gosta Leona
# 8            9         1       3          "Johnson   Mrs. Oscar W (Elisa
# 9           10         1       2           "Nasser   Mrs. Nicholas (Adel
# 10          11         1       3        "Sandstrom   Miss. Marguerite Ru
# 11          12         1       1          "Bonnell      Miss. Elizabeth"
# ...

# %%
dff.drop("Name", axis=1, inplace=True)

# %%
dff.drop("Cabin", axis=1, inplace=True)

# %%
dff
# Out:
#      Passenger  Survived  Pclass                 Fname     Sex  Age  Sibsb  \
# 0            1         0       3      Mr. Owen Harris"    male   22      1
# 1            2         1       1   Mrs. John Bradley (  female   38      1
# 2            3         1       3          Miss. Laina"  female   26      0
# 3            4         1       1   Mrs. Jacques Heath   female   35      1
# 4            5         0       3    Mr. William Henry"    male   35      0
# 5            6         0       3            Mr. James"    male    0      0
# 6            7         0       1        Mr. Timothy J"    male   54      0
# 7            8         0       3   Master. Gosta Leona    male    2      3
# 8            9         1       3   Mrs. Oscar W (Elisa  female   27      0
# 9           10         1       2   Mrs. Nicholas (Adel  female   14      1
# 10          11         1       3   Miss. Marguerite Ru  female    4      1
# ...

# %%
dff.drop("Passenger", axis=1, inplace=True)

# %%
dff
# Out:
#      Survived  Pclass                 Fname     Sex  Age  Sibsb  Parch  \
# 0           0       3      Mr. Owen Harris"    male   22      1      0
# 1           1       1   Mrs. John Bradley (  female   38      1      0
# 2           1       3          Miss. Laina"  female   26      0      0
# 3           1       1   Mrs. Jacques Heath   female   35      1      0
# 4           0       3    Mr. William Henry"    male   35      0      0
# 5           0       3            Mr. James"    male    0      0      0
# 6           0       1        Mr. Timothy J"    male   54      0      0
# 7           0       3   Master. Gosta Leona    male    2      3      1
# 8           1       3   Mrs. Oscar W (Elisa  female   27      0      2
# 9           1       2   Mrs. Nicholas (Adel  female   14      1      0
# 10          1       3   Miss. Marguerite Ru  female    4      1      1
# 11          1       1      Miss. Elizabeth"  female   58      0      0
# ...

# %%
dff.drop("Fname", axis=1, inplace=True)

# %%
df
# Out:
#      Passenger  Survived  Pclass              Name                 Fname  \
# 0            1         0       3           "Braund      Mr. Owen Harris"
# 1            2         1       1          "Cumings   Mrs. John Bradley (
# 2            3         1       3        "Heikkinen          Miss. Laina"
# 3            4         1       1         "Futrelle   Mrs. Jacques Heath
# 4            5         0       3            "Allen    Mr. William Henry"
# 5            6         0       3            "Moran            Mr. James"
# 6            7         0       1         "McCarthy        Mr. Timothy J"
# 7            8         0       3          "Palsson   Master. Gosta Leona
# 8            9         1       3          "Johnson   Mrs. Oscar W (Elisa
# 9           10         1       2           "Nasser   Mrs. Nicholas (Adel
# 10          11         1       3        "Sandstrom   Miss. Marguerite Ru
# 11          12         1       1          "Bonnell      Miss. Elizabeth"
# ...

# %%
dff
# Out:
#      Survived  Pclass     Sex  Age  Sibsb  Parch      Fare Embarked
# 0           0       3    male   22      1      0    7.2500        S
# 1           1       1  female   38      1      0   71.2833        C
# 2           1       3  female   26      0      0    7.9250        S
# 3           1       1  female   35      1      0   53.1000        S
# 4           0       3    male   35      0      0    8.0500        S
# 5           0       3    male    0      0      0    8.4583        Q
# 6           0       1    male   54      0      0   51.8625        S
# 7           0       3    male    2      3      1   21.0750        S
# 8           1       3  female   27      0      2   11.1333        S
# 9           1       2  female   14      1      0   30.0708        C
# 10          1       3  female    4      1      1   16.7000        S
# 11          1       1  female   58      0      0   26.5500        S
# 12          0       3    male   20      0      0    8.0500        S
# ...

# %%
sns.distplot(df["Age"])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dff["Sex"]= le.fit_transform(dff["Sex"])

# %%
dff.head()
# Out:
#    Survived  Pclass  Sex  Age  Sibsb  Parch     Fare Embarked
# 0         0       3    1   22      1      0   7.2500        S
# 1         1       1    0   38      1      0  71.2833        C
# 2         1       3    0   26      0      0   7.9250        S
# 3         1       1    0   35      1      0  53.1000        S
# 4         0       3    1   35      0      0   8.0500        S

# %%
dff["Embarked"]= le.fit_transform(dff["Embarked"])

# %%
dff
# Out:
#      Survived  Pclass  Sex  Age  Sibsb  Parch      Fare  Embarked
# 0           0       3    1   22      1      0    7.2500         3
# 1           1       1    0   38      1      0   71.2833         1
# 2           1       3    0   26      0      0    7.9250         3
# 3           1       1    0   35      1      0   53.1000         3
# 4           0       3    1   35      0      0    8.0500         3
# 5           0       3    1    0      0      0    8.4583         2
# 6           0       1    1   54      0      0   51.8625         3
# 7           0       3    1    2      3      1   21.0750         3
# 8           1       3    0   27      0      2   11.1333         3
# 9           1       2    0   14      1      0   30.0708         1
# 10          1       3    0    4      1      1   16.7000         3
# 11          1       1    0   58      0      0   26.5500         3
# 12          0       3    1   20      0      0    8.0500         3
# ...

# %%
from scipy.stats import zscore

z=np.abs(zscore(dff))
z
# Out:
# array([[0.78927234, 0.82737724, 0.73769513, ..., 0.47367361, 0.50244524,
#         0.58796609],
#        [1.2669898 , 1.56610693, 1.35557354, ..., 0.47367361, 0.78684566,
#         1.91264387],
#        [1.2669898 , 0.82737724, 1.35557354, ..., 0.47367361, 0.48885432,
#         0.58796609],
#        ...,
#        [0.78927234, 0.82737724, 1.35557354, ..., 2.00893337, 0.1762632 ,
#         0.58796609],
#        [1.2669898 , 1.56610693, 0.73769513, ..., 0.47367361, 0.04438095,
#         1.91264387],
#        [0.78927234, 0.82737724, 0.73769513, ..., 0.47367361, 0.49237789,
#         0.66233889]])

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([ 13,  16,  25,  27,  50,  59,  61,  68,  71,  86,  88, 118, 119,
#        159, 164, 167, 171, 180, 182, 201, 233, 258, 261, 266, 278, 299,
#        311, 324, 341, 360, 377, 380, 386, 437, 438, 438, 480, 527, 541,
#        542, 557, 567, 610, 630, 638, 678, 679, 683, 686, 689, 700, 716,
#        730, 736, 737, 742, 774, 779, 787, 792, 813, 824, 829, 846, 850,
#        858, 863, 885], dtype=int64), array([5, 4, 5, 6, 4, 4, 7, 4, 4, 5, 6, 6, 4, 4, 4, 5, 4, 4, 4, 4, 4, 6,
#        4, 4, 4, 6, 6, 4, 6, 5, 6, 6, 4, 5, 5, 6, 4, 6, 4, 4, 6, 5, 5, 3,
#        5, 5, 6, 4, 4, 6, 6, 6, 6, 5, 6, 6, 5, 6, 4, 4, 4, 4, 7, 4, 4, 5,
#        4, 5], dtype=int64))

# %%
dff.shape
# Out:
# (891, 8)

# %%
dfnew=dff[(z<3).all(axis=1)]
dfnew
# Out:
#      Survived  Pclass  Sex  Age  Sibsb  Parch      Fare  Embarked
# 0           0       3    1   22      1      0    7.2500         3
# 1           1       1    0   38      1      0   71.2833         1
# 2           1       3    0   26      0      0    7.9250         3
# 3           1       1    0   35      1      0   53.1000         3
# 4           0       3    1   35      0      0    8.0500         3
# 5           0       3    1    0      0      0    8.4583         2
# 6           0       1    1   54      0      0   51.8625         3
# 7           0       3    1    2      3      1   21.0750         3
# 8           1       3    0   27      0      2   11.1333         3
# 9           1       2    0   14      1      0   30.0708         1
# 10          1       3    0    4      1      1   16.7000         3
# 11          1       1    0   58      0      0   26.5500         3
# 12          0       3    1   20      0      0    8.0500         3
# ...

# %%
dfnew.shape
# Out:
# (824, 8)
