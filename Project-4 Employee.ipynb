# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("em.csv")
df.head()
df.shape
# Out:
# (22, 6)

# %%
sns.heatmap(df.isnull())

# %%
# hence we can see some NAN values, now to remove them have to use IMPUTER

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy= "most_frequent")

# %%
df['City'] = imp.fit_transform(df['City'].values.reshape(-1,1))

# %%
df['City']
# Out:
# 0       Toronto
# 1       Edmonto
# 2       Toronto
# 3      HongKong
# 4      HongKong
# 5      HongKong
# 6       BayArea
# 7     Hyderabad
# 8       newyork
# 9       newyork
# 10     HongKong
# 11     HongKong
# 12     HongKong
# 13     HongKong
# 14    Hyderabad
# 15      newyork
# 16      newyork
# 17      Edmonto
# 18        Congo
# 19       Angola
# 20      Finland
# 21       London
# Name: City, dtype: object

# %%
df['Age'] = imp.fit_transform(df['Age'].values.reshape(-1,1))

# %%
df['Age']
# Out:
# 0     28.0
# 1     31.0
# 2     34.0
# 3     26.0
# 4     30.0
# 5     26.0
# 6     43.0
# 7     38.0
# 8     50.0
# 9     26.0
# 10    26.0
# 11    30.0
# 12    22.0
# 13    43.0
# 14    38.0
# 15    26.0
# 16    27.0
# 17    31.0
# 18    34.0
# 19    32.0
# 20    26.0
# 21    27.0
# Name: Age, dtype: float64

# %%
df['Salary']= imp.fit_transform(df['Salary'].values.reshape(-1,1))

# %%
df['Salary']
# Out:
# 0     20000.0
# 1      3900.0
# 2      8000.0
# 3     66672.0
# 4      8300.0
# 5     30007.0
# 6      8300.0
# 7     54666.0
# 8     67666.0
# 9      8888.0
# 10    66672.0
# 11    34344.0
# 12    30007.0
# 13     8300.0
# 14    54666.0
# 15    67666.0
# 16     8888.0
# 17     8300.0
# 18    34432.0
# 19    34534.0
# 20    33451.0
# 21     8300.0
# Name: Salary, dtype: float64

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America   8300.0
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df['City'] = imp.fit_transform(df['City'].values.reshape(-1,1))

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America   8300.0
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
sns.heatmap(df.isnull())

# %%
df['Age'] = imp.fit_transform(df['Age'].values.reshape(-1,1))

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America   8300.0
# 5     6    Geet  26.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  26.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  26.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
sns.heatmap(df.isnull())

# %%
# so finally no NAN Values...

# %%
df.drop(['SNo'], axis = 1, inplace = True)
df
# Out:
#       Name   Age       City  Country   Salary
# 0      Tom  28.0    Toronto   Canada  20000.0
# 1      Lee  31.0    Edmonto   Canada   3900.0
# 2     Dave  34.0    Toronto   Canada   8000.0
# 3     Anik  26.0   HongKong     Asia  66672.0
# 4    kamal  30.0   HongKong  America   8300.0
# 5     Geet  26.0   HongKong     Asia  30007.0
# 6   Steven  43.0    BayArea  America   8300.0
# 7      Ram  38.0  Hyderabad     Asia  54666.0
# 8     hari  50.0    newyork  America  67666.0
# 9     yami  26.0    newyork  America   8888.0
# 10    Anik  26.0   HongKong     Asia  66672.0
# 11   kamal  30.0   HongKong  America  34344.0
# 12    Geet  22.0   HongKong     Asia  30007.0
# 13  Steven  43.0   HongKong  America   8300.0
# 14     Ram  38.0  Hyderabad     Asia  54666.0
# 15    hari  26.0    newyork  America  67666.0
# 16    yami  27.0    newyork  America   8888.0
# 17     Lee  31.0    Edmonto   Canada   8300.0
# 18  Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df = pd.DataFrame(data=df)

# %%
df.shape
# Out:
# (22, 5)

# %%
df['Country'] = le.fit_transform(df['Country'])
df['City'] = le.fit_transform(df['City'])

# %%
df
# Out:
#       Name   Age  City  Country   Salary
# 0      Tom  28.0     8        3  20000.0
# 1      Lee  31.0     3        3   3900.0
# 2     Dave  34.0     8        3   8000.0
# 3     Anik  26.0     5        2  66672.0
# 4    kamal  30.0     5        1   8300.0
# 5     Geet  26.0     5        2  30007.0
# 6   Steven  43.0     1        1   8300.0
# 7      Ram  38.0     6        2  54666.0
# 8     hari  50.0     9        1  67666.0
# 9     yami  26.0     9        1   8888.0
# 10    Anik  26.0     5        2  66672.0
# 11   kamal  30.0     5        1  34344.0
# 12    Geet  22.0     5        2  30007.0
# 13  Steven  43.0     5        1   8300.0
# 14     Ram  38.0     6        2  54666.0
# 15    hari  26.0     9        1  67666.0
# 16    yami  27.0     9        1   8888.0
# 17     Lee  31.0     3        3   8300.0
# 18  Andrew  34.0     2        0  34432.0
# 19   soham  32.0     0        0  34534.0
# 20    Grig  26.0     4        4  33451.0
# 21   Kiara  27.0     7        4   8300.0

# %%
x = df.iloc[:,1:-1].values
y = df.iloc[:,-1].values

y
# Out:
# array([20000.,  3900.,  8000., 66672.,  8300., 30007.,  8300., 54666.,
#        67666.,  8888., 66672., 34344., 30007.,  8300., 54666., 67666.,
#         8888.,  8300., 34432., 34534., 33451.,  8300.])

# %%
x
# Out:
# array([[28.,  8.,  3.],
#        [31.,  3.,  3.],
#        [34.,  8.,  3.],
#        [26.,  5.,  2.],
#        [30.,  5.,  1.],
#        [26.,  5.,  2.],
#        [43.,  1.,  1.],
#        [38.,  6.,  2.],
#        [50.,  9.,  1.],
#        [26.,  9.,  1.],
#        [26.,  5.,  2.],
#        [30.,  5.,  1.],
#        [22.,  5.,  2.],
#        [43.,  5.,  1.],
#        [38.,  6.,  2.],
#        [26.,  9.,  1.],
#        [27.,  9.,  1.],
#        [31.,  3.,  3.],
#        [34.,  2.,  0.],
#        [32.,  0.,  0.],
#        [26.,  4.,  4.],
#        [27.,  7.,  4.]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=.33, random_state=47)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.4304637884938629

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([34328.13211459, -3262.3913268 , 43990.37545175, 21005.28025189,
#        21005.28025189, 21005.28025189, 45626.98917708,  7235.74627027])

# %%
print(mean_squared_error(y_test,pred))
print(r2_score(y_test,pred))
# Out:
# 1112744396.1573272
# -0.956947352572274

# %%
t= np.array([30, 7, 4])
t
# Out:
# array([30,  7,  4])

# %%
td=t.reshape(1,-1)
td
# Out:
# array([[30,  7,  4]])

# %%
lr.predict(td)
# Out:
# array([10414.49788239])

# %%
# so predicted salary in London Europe for 30 year old candidate is 10414.49788239, where as actual salary in London Europe for 27 year old candidate is 8300.0
