# %%
import pandas as pd
import numpy as np

# %%
# !pip install mysql-connector

# %%
import mysql.connector 
con=mysql.connector.connect(
    host = "127.0.0.1",
    port= "3306",
    username= "root",
    password= "zeeshan@449",
    database = "mysql")

# %%
df=pd.read_sql_query("select * from studmarks", con)
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
def studentresult(xyz):
    fd= pd.read_sql_query(xyz, con)
    return (fd)

# %%
studentresult("select * from studmarks")
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
studentresult("select name from studmarks where english > 65")
# Out:
#      name
# 0    John
# 1  Ramesh
# 2    Annu
# 3   Farha
# 4  Mukesh

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
dfnew=pd.DataFrame (data=df)

# %%
dfnew
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
plt.boxplot(dfnew['Maths'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d7920b2e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d7920b978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d791faeb8>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d7920bda0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d7921c390>],
#  'means': []}

# %%
# can see outliers in Maths marks...

# %%
plt.boxplot(dfnew['English'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d79295f98>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d79129828>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d79295e48>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d79129eb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d79129f98>],
#  'means': []}

# %%
#no outliers in English

# %%
plt.boxplot(dfnew['Civics'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d791bf630>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d791bfcc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d791bf240>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d791c9390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d791c96d8>],
#  'means': []}

# %%
# we can see an ourlier here in civics..

# %%
plt.boxplot(dfnew['Physics'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d79353be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d7935e2b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d793537f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d7935e940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d7935ec88>],
#  'means': []}

# %%
# so no outlier here in physics marks...

# %%
sns.heatmap(dfnew.isnull())

# %%
# hence there are no NAN Values...

# %%
dfcorr=dfnew.corr()
dfcorr
# Out:
#               Maths   Physics  Chemistry   English   Biology  Economics  \
# Maths      1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# Physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# Chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# English   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# Biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# Economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# History   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# Civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             History    Civics
# Maths     -0.320846 -0.274629
# Physics    0.334082 -0.643266
# Chemistry -0.482710  0.210908
# English   -0.038775  0.186705
# Biology   -0.456131 -0.330060
# Economics -0.164953  0.043905
# History    1.000000 -0.048686
# Civics    -0.048686  1.000000

# %%
plt.figure(figsize=(10,12))
sns.heatmap(dfcorr, cmap="Reds", annot=True)

# %%
# changing catogorical data into muerical data using label encoder...
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le.transform(dfnew.iloc[:,])

# %%
x=dfnew.iloc[:,3:]
x
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics
# 0     55       45         56       87       21         52       89      65
# 1     75       96         78       64       90         61       58       2
# 2     25       54         89       76       95         87       56      74
# 3     78       96         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
# 5     45       87         52       89       55         89       87      52
# 6     55       64         61       58       75         58       64      61
# 7     54       76         87       56       25         56       76      87
# 8     55       63         89       75       78         75       63      89
# 9     96       46         77       83       58         83       46      77

# %%
z=np.abs(zscore(x))
z
# Out:
# array([[0.24916243, 1.39276651, 1.45310069, 1.26169862, 1.70618534,
#         1.49152635, 1.40755973, 0.18716723],
#        [0.83415247, 1.20910499, 0.20328352, 0.41570417, 0.98779152,
#         0.84303663, 0.85328751, 2.43317398],
#        [1.87413478, 0.93361271, 1.03147562, 0.4594625 , 1.18300723,
#         1.03037811, 0.99914862, 0.56150169],
#        [0.99664971, 1.20910499, 0.80560505, 0.48863473, 0.41776163,
#         1.17448693, 0.38653195, 0.64468712],
#        [0.08666519, 1.20910499, 0.20328352, 1.72845418, 1.22205037,
#         0.30983398, 0.9699764 , 0.31194538],
#        [0.79081988, 0.7499512 , 1.75426145, 1.40755973, 0.37871849,
#         1.17448693, 1.26169862, 0.3535381 ],
#        [0.24916243, 0.42344183, 1.07664973, 0.85328751, 0.40214437,
#         1.05919987, 0.41570417, 0.02079636],
#        [0.30332817, 0.18876323, 0.88089524, 0.99914862, 1.55001277,
#         1.2033087 , 0.4594625 , 1.10220702],
# ...

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
dfnew=x[(z<3).all(axis=1)]
dfnew
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics
# 0     55       45         56       87       21         52       89      65
# 1     75       96         78       64       90         61       58       2
# 2     25       54         89       76       95         87       56      74
# 3     78       96         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
# 5     45       87         52       89       55         89       87      52
# 6     55       64         61       58       75         58       64      61
# 7     54       76         87       56       25         56       76      87
# 8     55       63         89       75       78         75       63      89
# 9     96       46         77       83       58         83       46      77

# %%
dfnew.shape    # there are no outliers..
# Out:
# (10, 8)
