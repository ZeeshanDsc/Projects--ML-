# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('flight ticket.csv')
test = pd.read_csv('flight test.csv')
sample = pd.read_csv('Sample.csv')

# %%
test['Price']=sample.Price
df = pd.concat([train, test],ignore_index = True)

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy = "most_frequent") #to remove NAN values

# %%
df['Route'] = si.fit_transform(df['Route'].values.reshape(-1,1))
df['Total_Stops'] = si.fit_transform(df['Total_Stops'].values.reshape(-1,1))

# %%
# coverting into time stamp

# %%
df['Date_of_Journey']= pd.to_datetime(df['Date_of_Journey'])
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df['Arrival_Time'] = df['Arrival_Time'].str.split(' ').str[0]

# %%
df['Total_Stops']= df['Total_Stops'].replace('non-stop', '0 stop')
df['Halt']= df['Total_Stops'].str.split(' ').str[0] # adding a new column HALT
df['Halt']= df['Halt'].astype(int)   #convertin object to int

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  Halt
# 0    22:20        01:10   2h 50m      0 stop         No info   3897     0
# 1    05:50        13:15   7h 25m     2 stops         No info   7662     2
# 2    09:25        04:25      19h     2 stops         No info  13882     2
# 3    18:05        23:30   5h 25m      1 stop         No info   6218     1
# 4    16:50        21:35   4h 45m      1 stop         No info  13302     1

# %%
df['Halt'].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Halt'],
#       dtype='object')

# %%
df['Rt_1'] = df['Route'].str.split('?').str[0] 
df['Rt_2'] = df['Route'].str.split('?').str[1] 
df['Rt_3'] = df['Route'].str.split('?').str[2]
df['Rt_4'] = df['Route'].str.split('?').str[3] 
df['Rt_5'] = df['Route'].str.split('?').str[4]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  Halt  \
# 0    22:20        01:10   2h 50m      0 stop         No info   3897     0
# 1    05:50        13:15   7h 25m     2 stops         No info   7662     2
# 2    09:25        04:25      19h     2 stops         No info  13882     2
# 3    18:05        23:30   5h 25m      1 stop         No info   6218     1
# 4    16:50        21:35   4h 45m      1 stop         No info  13302     1
#
#    Rt_1   Rt_2   Rt_3  Rt_4 Rt_5
# ...

# %%
df['Rt_1'].fillna("None", inplace = True)
df['Rt_2'].fillna("None", inplace = True)
df['Rt_3'].fillna("None", inplace = True)
df['Rt_4'].fillna("None", inplace = True)
df['Rt_5'].fillna("None", inplace = True)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  Halt  \
# 0    22:20        01:10   2h 50m      0 stop         No info   3897     0
# 1    05:50        13:15   7h 25m     2 stops         No info   7662     2
# 2    09:25        04:25      19h     2 stops         No info  13882     2
# 3    18:05        23:30   5h 25m      1 stop         No info   6218     1
# 4    16:50        21:35   4h 45m      1 stop         No info  13302     1
#
#    Rt_1   Rt_2   Rt_3  Rt_4  Rt_5
# ...

# %% [markdown]
# df.drop(['Rt_1', 'Rt_2', 'Rt_3', 'Rt_4', 'Rt_5'], inplace= True, axis=1)
# # mistakenly removed these columns

# %%
df['Rt_1'] = df['Route'].str.split('?').str[0] 
df['Rt_2'] = df['Route'].str.split('?').str[1] 
df['Rt_3'] = df['Route'].str.split('?').str[2]
df['Rt_4'] = df['Route'].str.split('?').str[3] 
df['Rt_5'] = df['Route'].str.split('?').str[4]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  Halt  \
# 0    22:20        01:10   2h 50m      0 stop         No info   3897     0
# 1    05:50        13:15   7h 25m     2 stops         No info   7662     2
# 2    09:25        04:25      19h     2 stops         No info  13882     2
# 3    18:05        23:30   5h 25m      1 stop         No info   6218     1
# 4    16:50        21:35   4h 45m      1 stop         No info  13302     1
#
#    Rt_1   Rt_2   Rt_3  Rt_4 Rt_5
# ...

# %%
df['Rt_1'].fillna("None", inplace = True)
df['Rt_2'].fillna("None", inplace = True)
df['Rt_3'].fillna("None", inplace = True)
df['Rt_4'].fillna("None", inplace = True)
df['Rt_5'].fillna("None", inplace = True)

# %%
df.drop('Route', inplace = True, axis =1)
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time Arrival_Time  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi    22:20        01:10
# 1    Air India      2019-01-05   Kolkata    Banglore    05:50        13:15
# 2  Jet Airways      2019-09-06     Delhi      Cochin    09:25        04:25
# 3       IndiGo      2019-12-05   Kolkata    Banglore    18:05        23:30
# 4       IndiGo      2019-01-03  Banglore   New Delhi    16:50        21:35
#
#   Duration Total_Stops Additional_Info  Price  Halt  Rt_1   Rt_2   Rt_3  Rt_4  \
# 0   2h 50m      0 stop         No info   3897     0  BLR     DEL   None  None
# 1   7h 25m     2 stops         No info   7662     2  CCU    IXR    BBI    BLR
# 2      19h     2 stops         No info  13882     2  DEL    LKO    BOM    COK
# 3   5h 25m      1 stop         No info   6218     1  CCU    NAG     BLR  None
# 4   4h 45m      1 stop         No info  13302     1  BLR    NAG     DEL  None
#
#    Rt_5
# 0  None
# 1  None
# 2  None
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
#splitting duration into hours and minutes and creating 2 new columns hours and minutes
df['hours']= df['Duration'].str.split("h").str[0]
df['minutes']=df['Duration'].str.split("h").str[1]
df['minutes']=df['minutes'].str.split("m").str[0]

# %%
#df1=df.copy()
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time Arrival_Time  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi    22:20        01:10
# 1    Air India      2019-01-05   Kolkata    Banglore    05:50        13:15
# 2  Jet Airways      2019-09-06     Delhi      Cochin    09:25        04:25
# 3       IndiGo      2019-12-05   Kolkata    Banglore    18:05        23:30
# 4       IndiGo      2019-01-03  Banglore   New Delhi    16:50        21:35
#
#   Duration Total_Stops Additional_Info  Price  Halt  Rt_1   Rt_2   Rt_3  Rt_4  \
# 0   2h 50m      0 stop         No info   3897     0  BLR     DEL   None  None
# 1   7h 25m     2 stops         No info   7662     2  CCU    IXR    BBI    BLR
# 2      19h     2 stops         No info  13882     2  DEL    LKO    BOM    COK
# 3   5h 25m      1 stop         No info   6218     1  CCU    NAG     BLR  None
# 4   4h 45m      1 stop         No info  13302     1  BLR    NAG     DEL  None
#
#    Rt_5 hours minutes
# 0  None     2      50
# ...

# %%
#df['hours'].fillna("0", inplace = True)
#df['minutes'].fillna("0", inplace = True)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time Arrival_Time  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi    22:20        01:10
# 1    Air India      2019-01-05   Kolkata    Banglore    05:50        13:15
# 2  Jet Airways      2019-09-06     Delhi      Cochin    09:25        04:25
# 3       IndiGo      2019-12-05   Kolkata    Banglore    18:05        23:30
# 4       IndiGo      2019-01-03  Banglore   New Delhi    16:50        21:35
#
#   Duration Total_Stops Additional_Info  Price  Halt  Rt_1   Rt_2   Rt_3  Rt_4  \
# 0   2h 50m      0 stop         No info   3897     0  BLR     DEL   None  None
# 1   7h 25m     2 stops         No info   7662     2  CCU    IXR    BBI    BLR
# 2      19h     2 stops         No info  13882     2  DEL    LKO    BOM    COK
# 3   5h 25m      1 stop         No info   6218     1  CCU    NAG     BLR  None
# 4   4h 45m      1 stop         No info  13302     1  BLR    NAG     DEL  None
#
#    Rt_5 hours minutes
# 0  None     2      50
# ...

# %%
#df['minutes'].dtype

# %% [markdown]
# df['hours']= df['hours'].astype(int)
# df['minutes']= df['minutes'].astype(int)

# %%
df['hours'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time Arrival_Time  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi    22:20        01:10
# 1    Air India      2019-01-05   Kolkata    Banglore    05:50        13:15
# 2  Jet Airways      2019-09-06     Delhi      Cochin    09:25        04:25
# 3       IndiGo      2019-12-05   Kolkata    Banglore    18:05        23:30
# 4       IndiGo      2019-01-03  Banglore   New Delhi    16:50        21:35
#
#   Duration Total_Stops Additional_Info  Price  Halt  Rt_1   Rt_2   Rt_3  Rt_4  \
# 0   2h 50m      0 stop         No info   3897     0  BLR     DEL   None  None
# 1   7h 25m     2 stops         No info   7662     2  CCU    IXR    BBI    BLR
# 2      19h     2 stops         No info  13882     2  DEL    LKO    BOM    COK
# 3   5h 25m      1 stop         No info   6218     1  CCU    NAG     BLR  None
# 4   4h 45m      1 stop         No info  13302     1  BLR    NAG     DEL  None
#
#    Rt_5 hours minutes
# 0  None     2      50
# ...

# %%
df['minutes'].unique()
# Out:
# array([' 50', ' 25', '', ' 45', ' 30', ' 5', ' 15', ' 35', ' 10', ' 20',
#        ' 55', ' 40', nan], dtype=object)

# %%
df['hours']= df['hours'].str.split("m").str[0]

# %%
df['hours'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '41', '40'], dtype=object)

# %%
df['hours']= df['hours'].astype(int)
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# Halt                        int32
# Rt_1                       object
# Rt_2                       object
# Rt_3                       object
# Rt_4                       object
# Rt_5                       object
# hours                       int32
# minutes                    object
# dtype: object

# %%
#df['minutes']= df['minutes'].str.split("").str[0]
# as i have already converted Duration.. then dropping that column..
df.drop('Duration', inplace= True, axis=1)

# %%
df['minutes']=si.fit_transform(df['minutes'].values.reshape(-1,1))

# %%
df['minutes']= le.fit_transform(df['minutes'])

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time Arrival_Time  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi    22:20        01:10
# 1    Air India      2019-01-05   Kolkata    Banglore    05:50        13:15
# 2  Jet Airways      2019-09-06     Delhi      Cochin    09:25        04:25
# 3       IndiGo      2019-12-05   Kolkata    Banglore    18:05        23:30
# 4       IndiGo      2019-01-03  Banglore   New Delhi    16:50        21:35
#
#   Total_Stops Additional_Info  Price  Halt  Rt_1   Rt_2   Rt_3  Rt_4  Rt_5  \
# 0      0 stop         No info   3897     0  BLR     DEL   None  None  None
# 1     2 stops         No info   7662     2  CCU    IXR    BBI    BLR  None
# 2     2 stops         No info  13882     2  DEL    LKO    BOM    COK  None
# 3      1 stop         No info   6218     1  CCU    NAG     BLR  None  None
# 4      1 stop         No info  13302     1  BLR    NAG     DEL  None  None
#
#    hours  minutes
# 0      2       10
# 1      7        4
# ...

# %%
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Dep_Time                   object
# Arrival_Time               object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# Halt                        int32
# Rt_1                       object
# Rt_2                       object
# Rt_3                       object
# Rt_4                       object
# Rt_5                       object
# hours                       int32
# minutes                     int32
# dtype: object

# %%
df['Additional_Info']= le.fit_transform(df['Additional_Info'])

df['Airline']= le.fit_transform(df['Airline'])
df['Destination']= le.fit_transform(df['Destination'])
df['Source']= le.fit_transform(df['Source'])
#df['hours']= le.fit_transform(df['hours'])
df['Rt_1']= le.fit_transform(df['Rt_1'])
df['Rt_2']= le.fit_transform(df['Rt_2'])
df['Rt_3']= le.fit_transform(df['Rt_3'])
df['Rt_4']= le.fit_transform(df['Rt_4'])
df['Rt_5']= le.fit_transform(df['Rt_5'])

# %%
df.head()
# Out:
#    Airline Date_of_Journey  Source  Destination Dep_Time Arrival_Time  \
# 0        3      2019-03-24       0            5    22:20        01:10
# 1        1      2019-01-05       3            0    05:50        13:15
# 2        4      2019-09-06       2            1    09:25        04:25
# 3        3      2019-12-05       3            0    18:05        23:30
# 4        3      2019-01-03       0            5    16:50        21:35
#
#   Total_Stops  Additional_Info  Price  Halt  Rt_1  Rt_2  Rt_3  Rt_4  Rt_5  \
# 0      0 stop                8   3897     0     0    13    30    13     5
# 1     2 stops                8   7662     2     2    25     1     3     5
# 2     2 stops                8  13882     2     3    32     4     5     5
# 3      1 stop                8   6218     1     2    34     3    13     5
# 4      1 stop                8  13302     1     0    34     8    13     5
#
#    hours  minutes
# 0      2       10
# 1      7        4
# 2     19        0
# 3      5        4
# ...

# %%
df.dtypes
# Out:
# Airline                     int32
# Date_of_Journey    datetime64[ns]
# Source                      int32
# Destination                 int32
# Dep_Time                   object
# Arrival_Time               object
# Total_Stops                object
# Additional_Info             int32
# Price                       int64
# Halt                        int32
# Rt_1                        int32
# Rt_2                        int32
# Rt_3                        int32
# Rt_4                        int32
# Rt_5                        int32
# hours                       int32
# minutes                     int32
# dtype: object

# %%
# we have already converted this Total_stops  into Halt colums, so lets drop it..
df.drop('Total_Stops', inplace= True, axis =1)

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Dep_Time',
#        'Arrival_Time', 'Additional_Info', 'Price', 'Halt', 'Rt_1', 'Rt_2',
#        'Rt_3', 'Rt_4', 'Rt_5', 'hours', 'minutes'],
#       dtype='object')

# %%
# adding minutes and hours so that we can easily analyse the duration time in minutes, and now we can drop, hours, minutes,  Arrival and Dep time.
df['duration']=df['hours']*60 + df['minutes']

# %%
df.drop(['minutes', 'hours', 'Arrival_Time', 'Dep_Time'], inplace=True, axis =1)

# %%
df.head()
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Additional_Info    0
# Price              0
# Halt               0
# Rt_1               0
# Rt_2               0
# Rt_3               0
# Rt_4               0
# Rt_5               0
# duration           0
# dtype: int64

# %%
#now we have clean data to perform further operations in it.

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
kfold = KFold(n_splits=50, shuffle=True, random_state=100)

# %%
x = df.copy()

# %%
x.drop(['Price'], inplace=True, axis=1)

# %%
x.drop(['Date_of_Journey'], inplace=True, axis=1)

# %%
x.columns
x.head()
# Out:
#    Airline  Source  Destination  Additional_Info  Halt  Rt_1  Rt_2  Rt_3  \
# 0        3       0            5                8     0     0    13    30
# 1        1       3            0                8     2     2    25     1
# 2        4       2            1                8     2     3    32     4
# 3        3       3            0                8     1     2    34     3
# 4        3       0            5                8     1     0    34     8
#
#    Rt_4  Rt_5  duration
# 0    13     5       130
# 1     3     5       424
# 2     5     5      1140
# 3    13     5       304
# 4    13     5       248

# %%
y = df.Price

# %%
#benchmark_model=make_pipeline(RobustScaler(),lr).fit(x,y)

# %%
cvscore = cross_val_score(lr, x, y, cv=kfold, scoring = 'neg_mean_squared_error')

# %%
np.sqrt(-cvscore).mean()
# Out:
# 5886.234672818063

# %%
print(cvscore.mean())
print(cvscore.std())
# Out:
# 0.16126693403200532
# 0.03808356015157419

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=.25, random_state=46)

# %%
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
lr.score(x_train,y_train)
# Out:
# 0.16409969740377336

# %%
t = np.array([3, 0, 5, 8, 0, 0, 13, 30, 13, 5, 130]).reshape(1,-1)

# %%
lr.predict(t)
# Out:
# array([9271.87613782])
