# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix, accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import seaborn as sns

# %%
df1= pd.DataFrame(data=df)

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
plt.boxplot(df1['alcohol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ff8101748>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ff8101dd8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ff8101320>],
#  'medians': [<matplotlib.lines.Line2D at 0x19ff8101da0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19ff81087f0>],
#  'means': []}

# %%
plt.boxplot(df1['volatile acidity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ff814ee48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ff81587f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ff814ecf8>],
#  'medians': [<matplotlib.lines.Line2D at 0x19ff8158e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19ff8158dd8>],
#  'means': []}

# %%
plt.boxplot(df1["residual sugar"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19ff81a9f28>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19ff81b48d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19ff81a9dd8>],
#  'medians': [<matplotlib.lines.Line2D at 0x19ff81b4f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19ff81b4eb8>],
#  'means': []}

# %%
sns.countplot("volatile acidity", data= df1)

# %%
plt.scatter(x="volatile acidity", y='quality', data=df1)

# %%
# here we can see as volatile acidity increses quality decreases...

# %%
plt.scatter(x="quality", y='citric acid', data=df1)

# %%
sns.distplot(df1["quality"])

# %%
dfcorr = df1.corr()

# %%
dfcorr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(dfcorr, cmap="Blues", annot= True)

# %%
# here we can see volatile acidity is the least effective attribute for good wine quality.

# %%
sns.barplot(df1['quality'], df1['fixed acidity'])

# %%
sns.barplot(df1['quality'], df1['volatile acidity'])
plt.title("quality of wine with Volatile acidity")
plt.show()

# %%
# As volatile acidity increases quality of wine decreases

# %%
sns.barplot(df1['quality'], df1['citric acid'])
plt.title("quality of wine with citirc acid")
plt.show()

# %%
# as citric acid's value increases quality if wine also increases, hence it has positive impact on qine quality

# %%
sns.barplot(df1['quality'], df1['pH'])
plt.title("quality of wine with pH")
plt.show()

# %%
# we have almost similar pH value at every given point hence I could not found much impact.

# %%
sns.barplot(df1['quality'], df1['residual sugar'])
plt.title("quality of wine with residual sugar")
plt.show()

# %%
sns.barplot(df1['quality'], df1['free sulfur dioxide'])
plt.title("quality of wine with free sulfur dioxide")
plt.show()

# %%
# here we can see as value of FSDoxd increases upto 17 quality of wine is increasing and after that it starts decreasing ..

# %%
from sklearn.preprocessing import StandardScaler

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[0.52835961, 0.96187667, 1.39147228, ..., 0.57920652, 0.96024611,
#         0.78782264],
#        [0.29854743, 1.96744245, 1.39147228, ..., 0.1289504 , 0.58477711,
#         0.78782264],
#        [0.29854743, 1.29706527, 1.18607043, ..., 0.04808883, 0.58477711,
#         0.78782264],
#        ...,
#        [1.1603431 , 0.09955388, 0.72391627, ..., 0.54204194, 0.54162988,
#         0.45084835],
#        [1.39015528, 0.65462046, 0.77526673, ..., 0.30598963, 0.20930812,
#         0.78782264],
#        [1.33270223, 1.21684919, 1.02199944, ..., 0.01092425, 0.54162988,
#         0.45084835]])

# %%
threshold = 3
df1= df1[(z<3).all(axis=1)]
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
x=df1.iloc[:,0:-1].values
x
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
y=df1.iloc[:,-1].values
y
# Out:
# array([5, 5, 5, ..., 6, 5, 6], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=.33, random_state=46)

# %%
#Supervised learning - Logistic regression

lr = LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.6131687242798354

# %%
#Feature scaling
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(x_test)

# %%
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.6265432098765432

# %%
# here we can see after standard scaling we have very minor increase in score..

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([5, 5, 6, 5, 5, 6, 6, 6, 6, 6, 5, 5, 5, 6, 5, 5, 5, 7, 5, 7, 5, 5,
#        5, 5, 5, 6, 6, 5, 6, 5, 5, 6, 7, 6, 5, 6, 6, 6, 5, 5, 6, 5, 6, 5,
#        6, 5, 6, 6, 5, 6, 6, 6, 7, 5, 5, 5, 6, 5, 6, 7, 6, 5, 7, 6, 5, 5,
#        6, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 7, 5, 5, 5, 6, 7, 5, 7, 6, 7,
#        5, 5, 5, 6, 6, 5, 5, 5, 6, 7, 5, 5, 7, 5, 5, 5, 5, 6, 5, 5, 6, 5,
#        5, 5, 6, 6, 6, 6, 6, 7, 6, 5, 6, 6, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5,
#        5, 6, 5, 5, 6, 5, 5, 7, 6, 6, 6, 7, 6, 6, 6, 5, 6, 7, 5, 6, 5, 5,
#        6, 5, 5, 6, 6, 6, 5, 5, 6, 5, 5, 7, 7, 5, 6, 6, 6, 6, 5, 5, 6, 6,
#        6, 7, 5, 7, 6, 5, 5, 5, 6, 7, 6, 6, 7, 6, 5, 5, 5, 5, 6, 6, 5, 5,
#        7, 7, 6, 5, 6, 7, 5, 7, 5, 6, 5, 7, 6, 6, 5, 6, 6, 6, 5, 6, 5, 6,
#        6, 5, 6, 6, 5, 5, 5, 6, 5, 5, 7, 7, 6, 5, 5, 6, 5, 5, 6, 5, 7, 5,
#        6, 7, 6, 5, 5, 6, 7, 5, 6, 7, 6, 5, 6, 5, 6, 5, 5, 6, 5, 5, 6, 6,
#        6, 5, 5, 6, 5, 5, 5, 7, 6, 5, 5, 6, 5, 5, 5, 6, 6, 5, 5, 5, 6, 5,
# ...

# %%
print(accuracy_score(y_test, pred))
print(confusion_matrix(y_test, pred))
# Out:
# 0.592901878914405
# [[  0   9   4   0   0]
#  [  0 160  48   5   0]
#  [  0  60 106  24   0]
#  [  0   4  36  18   0]
#  [  0   0   3   2   0]]

# %%
#Applying SVM
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train,y_train)

predsvc=svc.predict(x_test)
print(confusion_matrix(y_test,predsvc))
print(accuracy_score(y_test,predsvc))
# Out:
# [[  0  11   2   0   0]
#  [  0 166  43   4   0]
#  [  0  60 115  15   0]
#  [  0   5  33  20   0]
#  [  0   0   3   2   0]]
# 0.6283924843423799

# %%
#unsupervised learning 

# K-means clustering..

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=3)
km=kmeans.fit(df1)
km
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
km.labels_
# Out:
# array([0, 2, 2, ..., 2, 2, 2])

# %%
km.cluster_centers_
# Out:
# array([[8.42444733e+00, 5.13517555e-01, 2.65747724e-01, 2.32282185e+00,
#         8.08140442e-02, 9.00260078e+00, 2.23784135e+01, 9.96564434e-01,
#         3.31326398e+00, 6.40663199e-01, 1.05851972e+01, 5.76853056e+00],
#        [7.89441624e+00, 5.76015228e-01, 2.68223350e-01, 2.54873096e+00,
#         8.35329949e-02, 2.32335025e+01, 1.02487310e+02, 9.96902234e-01,
#         3.31025381e+00, 6.21218274e-01, 9.96065990e+00, 5.28426396e+00],
#        [8.29752577e+00, 5.16350515e-01, 2.63649485e-01, 2.42391753e+00,
#         8.15381443e-02, 2.14783505e+01, 5.37340206e+01, 9.96863175e-01,
#         3.32247423e+00, 6.54309278e-01, 1.03479038e+01, 5.63917526e+00]])

# %%
pd.crosstab(df1['quality'],km.labels_)
# Out:
# col_0      0    1    2
# quality
# 4         30    4   13
# 5        270  144  203
# 6        330   39  217
# 7        126    9   50
# 8         13    1    2

# %%
from sklearn.metrics import homogeneity_score
print(homogeneity_score(km.labels_, df1['quality']))
# Out:
# 0.037752614547299224
